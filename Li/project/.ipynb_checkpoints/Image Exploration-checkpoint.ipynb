# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("snow_test.jpg", 0)
plt.imshow(img, 'gray')

print(img.shape) #960, 1296
# Out:
# (960, 1296)

# %%
# Laplacian transform

lap = cv2.Laplacian(img, cv2.CV_64F, ksize=3) # cv2.CV_64F float datatype
lap = np.uint8(np.absolute(lap)) # abs val of laplacian transformation, convert back to 8bit

plt.imshow(lap, 'gray')

# %%
# sobelX transform

sobelX = cv2.Sobel(img, cv2.CV_64F, 1, 0) 
sobelX = np.uint8(np.absolute(sobelX))

plt.imshow(sobelX, 'gray')

# %%
# sobelY transform

sobelY = cv2.Sobel(img, cv2.CV_64F, 0, 1)
sobelY = np.uint8(np.absolute(sobelY))

plt.imshow(sobelY, 'gray')

# %%
# combined sobel transform

sobelCombined = cv2.bitwise_or(sobelX, sobelY)

plt.imshow(sobelCombined, 'gray')

# %%
# dummy function
def nothing(x):
    pass


# create trackbar for canny edge detection threshold changes
cv2.namedWindow('canny')

# add lower and upper threshold slidebars to "canny"
cv2.createTrackbar('lower', 'canny', 0, 255, nothing)
cv2.createTrackbar('upper', 'canny', 0, 255, nothing)

while(1):
    
    lower = cv2.getTrackbarPos('lower', 'canny')
    upper = cv2.getTrackbarPos('upper', 'canny')   
    edges = cv2.Canny(img, lower, upper)  
    
    cv2.imshow('canny', edges)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:   # hit escape to quit
        break

cv2.destroyAllWindows()

# %%
# optimized canny trasnform based on trackbar results

canny = cv2.Canny(img, 52, 200) 

plt.imshow(canny, 'gray')

# %%
    # plotting all in one image
    
    titles = ['image', 'Laplacian', 'sobelX', 'sobelY', 'sobelCombined', 'canny']
    images = [img, lap, sobelX, sobelY, sobelCombined, canny]
    for i in range(6):
        plt.subplot(2, 3, i+1), plt.imshow(images[i], 'gray')
        plt.title(titles[i])
        plt.xticks([]),plt.yticks([])
    
    plt.show()

# %%
# probabilistic hough transform

# read this again
img = cv2.imread("snow_test.jpg", 0)

lines = cv2.HoughLinesP(canny,1,np.pi/180, 150,minLineLength=100,maxLineGap=12)

for line in lines:
    x1,y1,x2,y2 = line[0]
    cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)
    
cv2.imshow('image', img)
k = cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
height = image.shape[0]
width = image.shape[1]

region_of_interest_vertices = [
    (0,height),
    (0, height*0.60),
    (width/2, height/2),
    (width, height)
]

def region_of_interest(img, vertices):
    mask = np.zeros_like(img)
    channel_count = img.shape[2]
    match_mask_color = (255,) * channel_count
    cv2.fillPoly(mask, vertices, match_mask_color)
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

cropped_image = region_of_interest(image,
                np.array([region_of_interest_vertices], np.int32),)

plt.imshow(cropped_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-63c4c6f64f9f> in <module>
# ----> 1 height = image.shape[0]
#       2 width = image.shape[1]
#       3
#       4 region_of_interest_vertices = [
#       5     (0,height),
#
# NameError: name 'image' is not defined
